# %%
#| hide
from nbedev_test.core import *

# %% [markdown]
# # nbedev_test
#
# > A python module

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install nbedev_test in Development mode

# %% [markdown]
# ```sh
# # make sure nbedev_test package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to nbedev_test
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/schneider-clarify/nbedev_test.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c schneider-clarify nbedev_test
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install nbedev_test
# ```
#
#
# [repo]: https://github.com/schneider-clarify/nbedev_test
# [docs]: https://schneider-clarify.github.io/nbedev_test/
# [pypi]: https://pypi.org/project/nbedev_test/
# [conda]: https://anaconda.org/schneider-clarify/nbedev_test

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/schneider-clarify/nbedev_test
# [docs]: https://schneider-clarify.github.io/nbedev_test/
# [pypi]: https://pypi.org/project/nbedev_test/
# [conda]: https://anaconda.org/schneider-clarify/nbedev_test

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
